# %%
import numpy as np
import pandas as pd
import xlrd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("imputation_homework_87.xlsx")

# %%
df = pd.DataFrame(data, columns= ['date','value'])

# %%
df.interpolate(method ='linear', limit_direction ='forward')
# Out:
#           date      value
# 0   2015-11-03  13.394304
# 1   2015-11-04  -3.800715
# 2   2015-11-05  28.098152
# 3   2015-11-06  20.500562
# 4   2015-11-07  33.981955
# ..         ...        ...
# 847 2018-02-27  14.469096
# 848 2018-02-28  30.466798
# 849 2018-03-01  13.722157
# 850 2018-03-02  16.117787
# 851 2018-03-03  -8.030111
#
# [852 rows x 2 columns]

# %%
print(" \nCount total NaN at each column in a DataFrame : \n\n", df.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  date      0
# value    81
# dtype: int64

# %%
df.plot.hist(bins=12, alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ax1 = df.plot.scatter(x='date',
                      y='value',
                      c='DarkBlue')

# %%
pd.plotting.lag_plot(df, lag=1);
plt.title("Lag plot with lag=1");
plt.show(block=True);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1519         try:
# -> 1520             ret = self.converter.convert(x, self.units, self)
#    1521         except Exception as e:
#
# ~\anaconda3\lib\site-packages\matplotlib\dates.py in convert(value, unit, axis)
#    1905         """
# -> 1906         return date2num(value)
#    1907
#
# ~\anaconda3\lib\site-packages\matplotlib\dates.py in date2num(d)
#     443             return d
# --> 444         return _to_ordinalf_np_vectorized(d)
#     445
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in __call__(self, *args, **kwargs)
#    2107
# -> 2108         return self._vectorize_call(func=func, args=vargs)
#    2109
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in _vectorize_call(self, func, args)
#    2191
# -> 2192             outputs = ufunc(*inputs)
#    2193
#
# ~\anaconda3\lib\site-packages\matplotlib\dates.py in _to_ordinalf(dt)
#     298         dt = dt.replace(tzinfo=None)
# --> 299     dt64 = np.datetime64(dt)
#     300     return _dt64_to_ordinalf(dt64)
#
# ValueError: Could not convert object to NumPy datetime
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-33-acc667636424> in <module>
# ----> 1 pd.plotting.lag_plot(df, lag=1);
#       2 plt.title("Lag plot with lag=1");
#       3 plt.show(block=True);
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_misc.py in lag_plot(series, lag, ax, **kwds)
#     450     """
#     451     plot_backend = _get_plot_backend("matplotlib")
# --> 452     return plot_backend.lag_plot(series=series, lag=lag, ax=ax, **kwds)
#     453
#     454
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py in lag_plot(series, lag, ax, **kwds)
#     399     ax.set_xlabel("y(t)")
#     400     ax.set_ylabel(f"y(t + {lag})")
# --> 401     ax.scatter(y1, y2, **kwds)
#     402     return ax
#     403
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4431
#    4432         self._process_unit_info(xdata=x, ydata=y, kwargs=kwargs)
# -> 4433         x = self.convert_xunits(x)
#    4434         y = self.convert_yunits(y)
#    4435
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in convert_xunits(self, x)
#     173         if ax is None or ax.xaxis is None:
#     174             return x
# --> 175         return ax.xaxis.convert_units(x)
#     176
#     177     def convert_yunits(self, y):
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1520             ret = self.converter.convert(x, self.units, self)
#    1521         except Exception as e:
# -> 1522             raise munits.ConversionError('Failed to convert value(s) to axis '
#    1523                                          f'units: {x!r}') from e
#    1524         return ret
#
# ConversionError: Failed to convert value(s) to axis units: array([[Timestamp('2015-11-03 00:00:00'), 13.39430395943768],
#        [Timestamp('2015-11-04 00:00:00'), -3.800715003954167],
#        [Timestamp('2015-11-05 00:00:00'), 28.09815224865972],
#        ...,
#        [Timestamp('2018-02-28 00:00:00'), 30.46679789825012],
#        [Timestamp('2018-03-01 00:00:00'), 13.72215660169],
#        [Timestamp('2018-03-02 00:00:00'), 16.11778660210533]],
#       dtype=object)
